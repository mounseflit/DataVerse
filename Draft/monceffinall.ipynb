# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# %% [markdown]
# ### Load datasets

# %%
academic_df = pd.read_csv("./academic.csv")
academic_df.head()
# Out:
#                       SchoolDepartment  \
# 0      Quality Assurance and Risk Mgmt
# 1      Quality Assurance and Risk Mgmt
# 2     Quality Assurance and Risk Manag
# 3     Quality Assurance and Risk Manag
# 4  Quality Assurance & Risk Management
#
#                                  CourseTitle                      Email  \
# 0  Add Documents to 2020 Core Committee Page  kfoulstone0@instagram.com
# 1     White River High School Election Video  kfoulstone0@instagram.com
# 2               Pet License Roster Web Edits  kfoulstone0@instagram.com
# 3                      FJC Shred Event Flyer  kfoulstone0@instagram.com
# 4     Create Artwork for new Large Dropboxes  kfoulstone0@instagram.com
#
#                                        RequiredSkill               Professors  \
# 0                                Website Programming  Fatima Zahra El Idrissi
# 1                       Video Editing and Production  Fatima Zahra El Idrissi
# 2                                Website Programming  Fatima Zahra El Idrissi
# 3  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
# 4  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
#
#                                          GainedSkill strartingOrAsgnmtDate  \
# 0                                Website Programming            04-03-2019
# 1                                         04-03-2019           07:56:00 PM
# 2                                Website Programming            04-03-2019
# 3  Video Editing, Graphic Design, Technical Docum...            2019-03-04
# 4                                         11-03-2019              15:38:00
#
#           Hour
# 0  07:51:00 PM
# 1          NaN
# 2  08:12:00 PM
# 3     22:27:00
# 4          NaN

# %%
department_df = pd.read_csv("./department.csv")
department_df.head()
# Out:
#                                      name  \
# 0   Quality Assurance and Risk Management
# 1       Technical Communication and Media
# 2     Engineering Leadership and Strategy
# 3  Academic Affairs and Staff Development
# 4     Environmental and Civil Engineering
#
#                                          description  \
# 0  department that is responsible for ensuring th...
# 1  department that teaches you how to communicate...
# 2  department that is responsible for the develop...
# 3  department that is responsible for the academi...
# 4  department that is responsible for the design ...
#
#                    department_code         created_date   phone_number  \
# 0  dept_01JD8RJE3NTQPR3J6FGQ27DZ9Y  1968-12-28 09:24:59  2126442882953
# 1  dept_01JD8RJE3XDXME60264HHEEP5X  1929-05-29 14:51:03  2121135897138
# 2  dept_01JD8RJE3YZMB79PYNABBQDE9V  1937-03-30 22:13:39  2123731667078
# 3  dept_01JD8RJE3ZVC8A59TW7Q5PQ3K1  1971-06-04 00:51:39  2124593511982
# 4  dept_01JD8RJE40JJA5J75GDEJAJW5R  1920-12-08 09:16:51  2127308767779
#
#                       email
# 0      wgaunter0@meetup.com
# 1  wadshede1@feedburner.com
# 2   ovanderbeken2@jigsy.com
# 3           kdoxsey3@qq.com
# 4     fassiter4@nytimes.com

# %% [markdown]
# ### Clean and Standardize column names

# %%
academic_df.columns = academic_df.columns.str.lower().str.replace(' ', '_')
department_df.columns = department_df.columns.str.lower().str.replace(' ', '_')

# %%
academic_df.head()
# Out:
#                       schooldepartment  \
# 0      Quality Assurance and Risk Mgmt
# 1      Quality Assurance and Risk Mgmt
# 2     Quality Assurance and Risk Manag
# 3     Quality Assurance and Risk Manag
# 4  Quality Assurance & Risk Management
#
#                                  coursetitle                      email  \
# 0  Add Documents to 2020 Core Committee Page  kfoulstone0@instagram.com
# 1     White River High School Election Video  kfoulstone0@instagram.com
# 2               Pet License Roster Web Edits  kfoulstone0@instagram.com
# 3                      FJC Shred Event Flyer  kfoulstone0@instagram.com
# 4     Create Artwork for new Large Dropboxes  kfoulstone0@instagram.com
#
#                                        requiredskill               professors  \
# 0                                Website Programming  Fatima Zahra El Idrissi
# 1                       Video Editing and Production  Fatima Zahra El Idrissi
# 2                                Website Programming  Fatima Zahra El Idrissi
# 3  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
# 4  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
#
#                                          gainedskill strartingorasgnmtdate  \
# 0                                Website Programming            04-03-2019
# 1                                         04-03-2019           07:56:00 PM
# 2                                Website Programming            04-03-2019
# 3  Video Editing, Graphic Design, Technical Docum...            2019-03-04
# 4                                         11-03-2019              15:38:00
#
#           hour
# 0  07:51:00 PM
# 1          NaN
# 2  08:12:00 PM
# 3     22:27:00
# 4          NaN

# %%
# since we got a non understandable column name we rename some specific columns
academic_df.rename(columns={'schooldepartment': 'school_department'}, inplace=True)
academic_df.rename(columns={'coursetitle': 'course_title'}, inplace=True)
academic_df.rename(columns={'requiredskill': 'required_skill'}, inplace=True)
academic_df.rename(columns={'gainedskill': 'gained_skill'}, inplace=True)
academic_df.rename(columns={'strartingorasgnmtdate': 'starting_or_assignment_date'}, inplace=True)

# %%
academic_df.head()
# Out:
#                      school_department  \
# 0      Quality Assurance and Risk Mgmt
# 1      Quality Assurance and Risk Mgmt
# 2     Quality Assurance and Risk Manag
# 3     Quality Assurance and Risk Manag
# 4  Quality Assurance & Risk Management
#
#                                 course_title                      email  \
# 0  Add Documents to 2020 Core Committee Page  kfoulstone0@instagram.com
# 1     White River High School Election Video  kfoulstone0@instagram.com
# 2               Pet License Roster Web Edits  kfoulstone0@instagram.com
# 3                      FJC Shred Event Flyer  kfoulstone0@instagram.com
# 4     Create Artwork for new Large Dropboxes  kfoulstone0@instagram.com
#
#                                       required_skill               professors  \
# 0                                Website Programming  Fatima Zahra El Idrissi
# 1                       Video Editing and Production  Fatima Zahra El Idrissi
# 2                                Website Programming  Fatima Zahra El Idrissi
# 3  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
# 4  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
#
#                                         gained_skill  \
# 0                                Website Programming
# 1                                         04-03-2019
# 2                                Website Programming
# 3  Video Editing, Graphic Design, Technical Docum...
# 4                                         11-03-2019
#
#   starting_or_assignment_date         hour
# 0                  04-03-2019  07:51:00 PM
# 1                 07:56:00 PM          NaN
# 2                  04-03-2019  08:12:00 PM
# 3                  2019-03-04     22:27:00
# 4                    15:38:00          NaN

# %%
department_df.head()
# Out:
#                                      name  \
# 0   Quality Assurance and Risk Management
# 1       Technical Communication and Media
# 2     Engineering Leadership and Strategy
# 3  Academic Affairs and Staff Development
# 4     Environmental and Civil Engineering
#
#                                          description  \
# 0  department that is responsible for ensuring th...
# 1  department that teaches you how to communicate...
# 2  department that is responsible for the develop...
# 3  department that is responsible for the academi...
# 4  department that is responsible for the design ...
#
#                    department_code         created_date   phone_number  \
# 0  dept_01JD8RJE3NTQPR3J6FGQ27DZ9Y  1968-12-28 09:24:59  2126442882953
# 1  dept_01JD8RJE3XDXME60264HHEEP5X  1929-05-29 14:51:03  2121135897138
# 2  dept_01JD8RJE3YZMB79PYNABBQDE9V  1937-03-30 22:13:39  2123731667078
# 3  dept_01JD8RJE3ZVC8A59TW7Q5PQ3K1  1971-06-04 00:51:39  2124593511982
# 4  dept_01JD8RJE40JJA5J75GDEJAJW5R  1920-12-08 09:16:51  2127308767779
#
#                       email
# 0      wgaunter0@meetup.com
# 1  wadshede1@feedburner.com
# 2   ovanderbeken2@jigsy.com
# 3           kdoxsey3@qq.com
# 4     fassiter4@nytimes.com

# %% [markdown]
# ### Handle Missing Values

# %%
### Let's check first how much missed values are in our dataframes
print("\nMissing values in Academic Dataset:")
print(academic_df.isnull().sum())
print("\nMissing values in Department Dataset:")
print(department_df.isnull().sum())
# Out:
# Missing values in Academic Dataset:
# school_department                1
# course_title                     2
# email                            0
# required_skill                   0
# professors                       4
# gained_skill                     2
# starting_or_assignment_date     16
# hour                           192
# dtype: int64
#
# Missing values in Department Dataset:
# name               0
# description        0
# department_code    0
# created_date       0
# phone_number       0
# email              0
# dtype: int64

# %%
academic_df
# Out:
#                            school_department  \
# 0            Quality Assurance and Risk Mgmt
# 1            Quality Assurance and Risk Mgmt
# 2           Quality Assurance and Risk Manag
# 3           Quality Assurance and Risk Manag
# 4        Quality Assurance & Risk Management
# ...                                      ...
# 2134                                     NaN
# 2135                    Financal Engineering
# 2136         Urban Planning and Public Infra
# 2137  Urban Planning & Public Infrastructure
# 2138  Urban Planning & Public Infrastructure
#
#                                    course_title                      email  \
# 0     Add Documents to 2020 Core Committee Page  kfoulstone0@instagram.com
# 1        White River High School Election Video  kfoulstone0@instagram.com
# 2                  Pet License Roster Web Edits  kfoulstone0@instagram.com
# 3                         FJC Shred Event Flyer  kfoulstone0@instagram.com
# 4        Create Artwork for new Large Dropboxes  kfoulstone0@instagram.com
# ...                                         ...                        ...
# 2134                                        NaN                    unvalid
# 2135                     Tyler Award Submission                    unvalid
# 2136                   Stormwater Manual Update                    unvalid
# 2137                   Stormwater Manual Update                    unvalid
# 2138                   Stormwater Manual Update                    unvalid
#
#                                          required_skill  \
# 0                                   Website Programming
# 1                          Video Editing and Production
# 2                                   Website Programming
# 3     Graphic Design/Marketing (Posters, Brochures, ...
# 4     Graphic Design/Marketing (Posters, Brochures, ...
# ...                                                 ...
# 2134                                         2020-12-10
# 2135                                         2021-01-15
# 2136                                Website Programming
# 2137                                Website Programming
# 2138                                Website Programming
#
#                    professors  \
# 0     Fatima Zahra El Idrissi
# 1     Fatima Zahra El Idrissi
# 2     Fatima Zahra El Idrissi
# 3     Fatima Zahra El Idrissi
# 4     Fatima Zahra El Idrissi
# ...                       ...
# 2134              09:08:00 PM
# 2135              08:13:00 PM
# 2136                      NaN
# 2137                      NaN
# 2138                      NaN
#
#                                            gained_skill  \
# 0                                   Website Programming
# 1                                            04-03-2019
# 2                                   Website Programming
# 3     Video Editing, Graphic Design, Technical Docum...
# 4                                            11-03-2019
# ...                                                 ...
# 2134                                                NaN
# 2135                                                NaN
# 2136                                         2021-02-17
# 2137                                         2021-02-17
# 2138                                         17-02-2021
#
#      starting_or_assignment_date         hour
# 0                     04-03-2019  07:51:00 PM
# 1                    07:56:00 PM          NaN
# 2                     04-03-2019  08:12:00 PM
# 3                     2019-03-04     22:27:00
# 4                       15:38:00          NaN
# ...                          ...          ...
# 2134                         NaN          NaN
# 2135                         NaN          NaN
# 2136                    23:21:00          NaN
# 2137                 11:25:00 PM          NaN
# 2138                    23:30:00          NaN
#
# [2139 rows x 8 columns]

# %%
# Impute missing 'hour' column in academic_df
academic_df['hour'] = academic_df['hour'].fillna('00:00:00')

# Fill missing values in other columns by 'unknown'
academic_df.fillna('unknown', inplace=True)
academic_df.fillna('unknown', inplace=True)

# %%
print("\nMissing values in Academic Dataset:")
print(academic_df.isnull().sum())
print("\nMissing values in Department Dataset:")
print(department_df.isnull().sum())
# As we can see we removed successfully all NaN values
# Out:
# Missing values in Academic Dataset:
# school_department              0
# course_title                   0
# email                          0
# required_skill                 0
# professors                     0
# gained_skill                   0
# starting_or_assignment_date    0
# hour                           0
# dtype: int64
#
# Missing values in Department Dataset:
# name               0
# description        0
# department_code    0
# created_date       0
# phone_number       0
# email              0
# dtype: int64

# %%
# Standardize department names by making everything in lower case
academic_df['school_department'] = academic_df['school_department'].str.lower().str.strip()
department_df['name'] = department_df['name'].str.lower().str.strip()

# Handle special characters in department name like that & become "and"
academic_df['school_department'] = academic_df['school_department'].str.replace('&', 'and')
academic_df[:1]
# Out:
#                  school_department                               course_title  \
# 0  quality assurance and risk mgmt  Add Documents to 2020 Core Committee Page
#
#                        email       required_skill               professors  \
# 0  kfoulstone0@instagram.com  Website Programming  Fatima Zahra El Idrissi
#
#           gained_skill starting_or_assignment_date         hour
# 0  Website Programming                  04-03-2019  07:51:00 PM

# %%
academic_df
# Out:
#                              school_department  \
# 0              quality assurance and risk mgmt
# 1              quality assurance and risk mgmt
# 2             quality assurance and risk manag
# 3             quality assurance and risk manag
# 4        quality assurance and risk management
# ...                                        ...
# 2134                                   unknown
# 2135                      financal engineering
# 2136           urban planning and public infra
# 2137  urban planning and public infrastructure
# 2138  urban planning and public infrastructure
#
#                                    course_title                      email  \
# 0     Add Documents to 2020 Core Committee Page  kfoulstone0@instagram.com
# 1        White River High School Election Video  kfoulstone0@instagram.com
# 2                  Pet License Roster Web Edits  kfoulstone0@instagram.com
# 3                         FJC Shred Event Flyer  kfoulstone0@instagram.com
# 4        Create Artwork for new Large Dropboxes  kfoulstone0@instagram.com
# ...                                         ...                        ...
# 2134                                    unknown                    unvalid
# 2135                     Tyler Award Submission                    unvalid
# 2136                   Stormwater Manual Update                    unvalid
# 2137                   Stormwater Manual Update                    unvalid
# 2138                   Stormwater Manual Update                    unvalid
#
#                                          required_skill  \
# 0                                   Website Programming
# 1                          Video Editing and Production
# 2                                   Website Programming
# 3     Graphic Design/Marketing (Posters, Brochures, ...
# 4     Graphic Design/Marketing (Posters, Brochures, ...
# ...                                                 ...
# 2134                                         2020-12-10
# 2135                                         2021-01-15
# 2136                                Website Programming
# 2137                                Website Programming
# 2138                                Website Programming
#
#                    professors  \
# 0     Fatima Zahra El Idrissi
# 1     Fatima Zahra El Idrissi
# 2     Fatima Zahra El Idrissi
# 3     Fatima Zahra El Idrissi
# 4     Fatima Zahra El Idrissi
# ...                       ...
# 2134              09:08:00 PM
# 2135              08:13:00 PM
# 2136                  unknown
# 2137                  unknown
# 2138                  unknown
#
#                                            gained_skill  \
# 0                                   Website Programming
# 1                                            04-03-2019
# 2                                   Website Programming
# 3     Video Editing, Graphic Design, Technical Docum...
# 4                                            11-03-2019
# ...                                                 ...
# 2134                                            unknown
# 2135                                            unknown
# 2136                                         2021-02-17
# 2137                                         2021-02-17
# 2138                                         17-02-2021
#
#      starting_or_assignment_date         hour
# 0                     04-03-2019  07:51:00 PM
# 1                    07:56:00 PM     00:00:00
# 2                     04-03-2019  08:12:00 PM
# 3                     2019-03-04     22:27:00
# 4                       15:38:00     00:00:00
# ...                          ...          ...
# 2134                     unknown     00:00:00
# 2135                     unknown     00:00:00
# 2136                    23:21:00     00:00:00
# 2137                 11:25:00 PM     00:00:00
# 2138                    23:30:00     00:00:00
#
# [2139 rows x 8 columns]

# %%
# Merge datasets on a common column "school_department"
merged_df = pd.merge(academic_df, department_df, left_on='school_department', right_on='name', how='inner')
merged_df.head()
# Out:
#                         school_department  \
# 0   quality assurance and risk management
# 1   quality assurance and risk management
# 2   quality assurance and risk management
# 3  academic affairs and staff development
# 4       technical communication and media
#
#                              course_title                    email_x  \
# 0  Create Artwork for new Large Dropboxes  kfoulstone0@instagram.com
# 1               Redesign Election Inserts  kfoulstone0@instagram.com
# 2                         Kennel Brochure  kfoulstone0@instagram.com
# 3        LinkedIn Learning employee video  kfoulstone0@instagram.com
# 4                         Social Planning  kfoulstone0@instagram.com
#
#                                       required_skill               professors  \
# 0  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
# 1  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
# 2  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
# 3                       Video Editing and Production  Fatima Zahra El Idrissi
# 4                              Social Media Strategy  Fatima Zahra El Idrissi
#
#                                         gained_skill  \
# 0                                         11-03-2019
# 1  Graphic Design, Proofreading and Quality Assur...
# 2  Graphic Design, Proofreading and Quality Assur...
# 3                       Video Editing and Production
# 4                              Social Media Strategy
#
#   starting_or_assignment_date         hour  \
# 0                    15:38:00     00:00:00
# 1                  15-03-2019  07:26:00 PM
# 2                  2019-03-15  07:40:00 PM
# 3                  26-03-2019  10:07:00 PM
# 4                  2019-04-16  07:04:00 PM
#
#                                      name  \
# 0   quality assurance and risk management
# 1   quality assurance and risk management
# 2   quality assurance and risk management
# 3  academic affairs and staff development
# 4       technical communication and media
#
#                                          description  \
# 0  department that is responsible for ensuring th...
# 1  department that is responsible for ensuring th...
# 2  department that is responsible for ensuring th...
# 3  department that is responsible for the academi...
# 4  department that teaches you how to communicate...
#
#                    department_code         created_date   phone_number  \
# 0  dept_01JD8RJE3NTQPR3J6FGQ27DZ9Y  1968-12-28 09:24:59  2126442882953
# 1  dept_01JD8RJE3NTQPR3J6FGQ27DZ9Y  1968-12-28 09:24:59  2126442882953
# 2  dept_01JD8RJE3NTQPR3J6FGQ27DZ9Y  1968-12-28 09:24:59  2126442882953
# 3  dept_01JD8RJE3ZVC8A59TW7Q5PQ3K1  1971-06-04 00:51:39  2124593511982
# 4  dept_01JD8RJE3XDXME60264HHEEP5X  1929-05-29 14:51:03  2121135897138
#
#                     email_y
# 0      wgaunter0@meetup.com
# 1      wgaunter0@meetup.com
# 2      wgaunter0@meetup.com
# 3           kdoxsey3@qq.com
# 4  wadshede1@feedburner.com

# %%
# Combine required and gained skills
merged_df['skills_combined'] = merged_df['required_skill'] + " " + merged_df['gained_skill']

# Encode text features using TF-IDF
tfidf = TfidfVectorizer(max_features=100)
skills_tfidf = tfidf.fit_transform(merged_df['skills_combined']).toarray()

# Add TF-IDF features back to the dataframe
skills_df = pd.DataFrame(skills_tfidf, columns=[f'skill_tfidf_{i}' for i in range(skills_tfidf.shape[1])])
merged_df = pd.concat([merged_df.reset_index(drop=True), skills_df], axis=1)

# Encode categorical columns
le = LabelEncoder()
merged_df['school_department_encoded'] = le.fit_transform(merged_df['school_department'])
merged_df['professors_encoded'] = le.fit_transform(merged_df['professors'])

# Select numerical features for clustering
numerical_features = merged_df.select_dtypes(include=['float64', 'int64']).dropna(axis=1)

# Reduce dimensionality for visualization
pca = PCA(n_components=2)
reduced_features = pca.fit_transform(numerical_features)

# List of clustering algorithms
clustering_algorithms = {
    "KMeans": KMeans(n_clusters=5, random_state=42),
    "AgglomerativeClustering": AgglomerativeClustering(n_clusters=5),
    "DBSCAN": DBSCAN(eps=0.5, min_samples=5),
    "GaussianMixture": GaussianMixture(n_components=5, random_state=42)
}

# Dictionary to store evaluation metrics
results = {}

# Apply clustering algorithms, evaluate, and save models
for name, model in clustering_algorithms.items():
    # Fit or predict clusters
    if name == "GaussianMixture":
        model.fit(numerical_features)
        clusters = model.predict(numerical_features)
    else:
        clusters = model.fit_predict(numerical_features)

    # Add cluster labels to DataFrame
    merged_df[f"{name}_cluster"] = clusters

    # Compute evaluation metrics
    silhouette_avg = silhouette_score(numerical_features, clusters) if len(set(clusters)) > 1 else np.nan
    calinski_harabasz = calinski_harabasz_score(numerical_features, clusters) if len(set(clusters)) > 1 else np.nan
    davies_bouldin = davies_bouldin_score(numerical_features, clusters) if len(set(clusters)) > 1 else np.nan

    # Store metrics in results
    results[name] = {
        "Silhouette Score": silhouette_avg,
        "Calinski-Harabasz Index": calinski_harabasz,
        "Davies-Bouldin Index": davies_bouldin
    }

    # Save model
    with open(f"{name}_model.pkl", "wb") as file:
        pickle.dump(model, file)

    # Plot clusters
    plt.figure(figsize=(8, 6))
    plt.scatter(
        reduced_features[:, 0],
        reduced_features[:, 1],
        c=clusters,
        cmap="viridis",
        s=10
    )
    plt.title(f"{name} Clustering")
    plt.xlabel("PCA Feature 1")
    plt.ylabel("PCA Feature 2")
    plt.colorbar(label="Cluster")
    plt.show()

# Print evaluation results
print("Clustering Evaluation Metrics:\n")
for name, metrics in results.items():
    print(f"{name}:")
    for metric_name, value in metrics.items():
        print(f"  {metric_name}: {value:.4f}")
    print()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/mixture/_base.py:270: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# Clustering Evaluation Metrics:
#
# KMeans:
#   Silhouette Score: 0.8459
#   Calinski-Harabasz Index: 8129.8588
#   Davies-Bouldin Index: 0.2200
#
# AgglomerativeClustering:
#   Silhouette Score: 0.8414
#   Calinski-Harabasz Index: 8393.5712
#   Davies-Bouldin Index: 0.2508
#
# DBSCAN:
#   Silhouette Score: 0.9437
#   Calinski-Harabasz Index: 1446.2251
#   Davies-Bouldin Index: 2.3880
#
# GaussianMixture:
#   Silhouette Score: -0.0961
#   Calinski-Harabasz Index: 60.9923
#   Davies-Bouldin Index: 1.8848
